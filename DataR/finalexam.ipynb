# %% [markdown]
# ## 1)
# ##### Which of the following is finally produced by Hierarchical Clustering?
# ###### b tree showing how close things
#
# ##### Which of the following is true about Residuals ?
# ###### a lower better
#
# ##### Which of the following is required by K-means clustering?
# ###### d all of  above
#
# ##### Which of the following-methods-use-find-best-fit-line-data-linear-regression?
# ###### a LSE
#
# ##### Which of the following evaluation metrics can be used to evaluate a model while modeling a continuous output variable?
# ###### d mean squared error

# %% [markdown]
# ## 2)
#
# ##### Cubic because its a third order curve  that closely fits the green line.
#
# ##### Constant is underfitting the data meaning we lose the significance of what we are predicting. It has very low variance and high bias thus should be discarded.
#
# ##### the 9th degree is overfitting line, creating trends and changes in direction beyond the true green line curve, making the predictions unreliable at any given point between observsed samples.
#
# ##### the linear model while simple and significant enough to show a trend, cubic curve is far closer the observed samples while maintaing the most true trend.

# %% [markdown]
# ## 3)  *suppose we have dataset of 10 samples with id*
#
# s1,s2,s3,s6,s7 (dataset 3)
#
# s1,s2,s3,s4,s5 (Dataset 1)
# s4,s5,s8,s9,s10 |(dataset 4)
# s1,s4,s6,s8,s10 (dataset 5)
#
# s6,s7,s8,s9,s10 (Dataset 2)
# s1,s2,s3,s6,s7 (dataset 3)
#
# s1,s2,s3,s4,s5 (Dataset 1)
# s4,s5,s8,s9,s10 (dataset 4)
# s1,s4,s6,s8,s10 (dataset 5)
#
# s6,s7,s8,s9,s10 (Dataset 2)

# %% [markdown]
# ## 4)  Suppose that they continue to toss the coin afterwards, what is the probability that Henry will win the entire prize?
#
# Pr(x=H) = 0.4 Pr(x=T) = 0.6
#
#   Pr(H wins  1H,2T) = Pr(H wins & first 3 rounds are 1H,2T)/Pr(1H,2T in first 3 rounds)
#
# = Pr(1H,2T in first 3 rounds) * P(4th = H,5th = H)/ Pr(1H,2T in first 3 rounds)
#
# = Pr(4th = H, 5th = H)
#
# = .4 * .4
#
# = .16
#
# Hillary has 16% chance to win the entire prize.

# %% [markdown]
# ## 5)  write commands

# %%
#1
install.packages("dplyr")
library(dplyr)
#2 write a command to remove all var in workspace
rm(list = ls())
#3 show help info of lm()function
? lm()
#4 get the dimension of dataframe 'df'
df = data.frame(c(5,6,3,2,2,4,1), c(2,4,3,2,5,6,3),c(3,4,5,2,2,6,3))
dim(df)
# Out:
# Warning message:
# "package 'dplyr' is in use and will not be installed"
# [1] 7 3
# lm                    package:stats                    R Documentation
#
# s
#
# n:
#
#      'lm' is used to fit linear models.  It can be used to carry out
#      regression, single stratum analysis of variance and analysis of
#      covariance (although 'aov' may provide a more convenient interface
#      for these).
#
# e:
#
#      lm(formula, data, subset, weights, na.action,
#         method = "qr", model = TRUE, x = FALSE, y = FALSE, qr = TRUE,
#         singular.ok = TRUE, contrasts = NULL, offset, ...)
#
# s:
#
#  formula: an object of class '"formula"' (or one that can be coerced to
#           that class): a symbolic description of the model to be
#           fitted.  The details of model specification are given under
#           'Details'.
#
#     data: an optional data frame, list or environment (or object
#           coercible by 'as.data.frame' to a data frame) containing the
# ...

# %% [markdown]
# ## 6)
#
# #1 2 aaba 3 aababaa
#
# #2 3 abbb 4 bbc 5 bbbbbbbbb
#
# #3  5 aaaaaaa 2 abcvc 3 abcbcbcbc 4 ac

# %% [markdown]
# ## 7)
#
# #1. T
# because most of R codes i.e about 50% are written in C and some hefty chunks are written C/C++because most of R codes i.e about 50% are written in C and some hefty chunks are written C/C++
#
# #2. T
# because it can sort data into clusters of various shapes. DBSCAN is a clustering method used to separate high density clusters from low density clusters in machine learningbecause it can sort data into clusters of various shapes. DBSCAN is a clustering method used to separate high density clusters from low density clusters in machine learning
#
# #3. F
# because Bernouli models in NLP Bayes classification computes the similarity between two documents based on binary data.because Bernouli models in NLP Bayes classification computes the similarity between two documents based on binary data.
#
# #4. F
# because a small change in data would change the decicion tree,due to its hierarchical nature of the tree building procedure.because a small change in data would change the decicion tree,due to its hierarchical nature of the tree building procedure.
#
# #5. T
# because L2 regularization is used for shrinkage or reduce the weights.because L2 regularization is used for shrinkage or reduce the weights.

# %% [markdown]
# ## 8.)
#  *Your dataset has 20 features.You want to choose features for your linear regression model.*
#
# ###### We start with a null model with no predictors.
# ###### In the first round we have 20 models for 20 features with no predictors called the null model.
# ###### Then we add the variable that gave the lowest test error thus strongest predictor in the second round.
# ###### In the second round we now fitting 19 models adding another variable to our single variable model, resulting in two-variable model.
# ###### We keep repeating this process until we have no statistically significant improvements of the fit of the model.

# %% [markdown]
# ## 9)
#
# #1. T
# knn,kmeans,Dbscan are unsupervised clustering methods and users could between distance measures i.e Min Max to compute the distance between two clusters
#
# #2. T
# Although SVM can not handle the nonlinear cases,it usually yields good results in practice.this is because it tries to find an optimal or maximum margin hyper-plane.
#
# #3. F
# Linear Regression and logestice Regression are are different regression methods and they could be leveraged to compute the same problem.
#
# #4. T
# The output of artificial neural network(ANN) can be either continuous or discreate.
#
# #5. T
# 5 fold cross validation could be applied to aid in both model selection and feature selection.

# %%
2. F unlikely but possible if train set is smaller than test set, leads to overfitting

3. F Linear Regression and logestice Regression are are different regression methods and they could be leveraged to compute the same problem

4. T GLM model an ordinary liner regression can be discrete

# %% [markdown]
# ## 10)

# %%
library(dplyr)
# Out:
# Warning message:
# "package 'dplyr' was built under R version 4.0.5"
# Registered S3 methods overwritten by 'tibble':
#   method     from
#   format.tbl pillar
#   print.tbl  pillar
#
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
dice=data.frame(c(5,6,3,2,2,4,1), c(2,4,3,2,5,6,3),c(7,1,5,2,2,6,3),c(6,2,3,2,5,1,5),c(2,4,1,5,2,6,3),c(2,2,4,2,2,2,2))

row.names= c('dice1','dice2','dice3','dice4','dice5','dice6','dice7')

colnames(dice) =c('1','2','3','4','5','6')

# %%
data  <- dice[c(3,4),] %>% 
    select(1,3,5)
data
# Out:
#   1 3 5
# 3 3 5 1
# 4 2 2 5

# %%
dice['total']=apply(dice,1, function(x) sum(x))

# %%
dice
# Out:
#   1 2 3 4 5 6 total
# 1 5 2 7 6 2 2 24
# 2 6 4 1 2 4 2 19
# 3 3 3 5 3 1 4 19
# 4 2 2 2 2 5 2 15
# 5 2 5 2 5 2 2 18
# 6 4 6 6 1 6 2 25
# 7 1 3 3 5 3 2 17
