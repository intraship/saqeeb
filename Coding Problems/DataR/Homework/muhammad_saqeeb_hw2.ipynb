# %%
#1 IBM
IBM <- read.csv("C:/Users/Administrator/data/IBM.csv") 
#2 MSFT
MSFT  <- read.csv("C:/Users/Administrator/data/MSFT.csv") 
#3 google
GOOG <- read.csv("C:/Users/Administrator/data/GOOG.csv") 
#4 apple
AAPL- read.csv("C:/Users/Administrator/data/AAPL.csv") 
#5 amazon
AMZN <- read.csv("C:/Users/Administrator/data/AMZN.csv") 
#6 meta (fb)
FB <- read.csv("C:/Users/Administrator/data/IBM.csv") 

library(dplyr) 
bull <- filter(IBM, IBM$Open<IBM$Close) 
bear <- filter(IBM, IBM$Open>IBM$Close) 
mean(bull$Volume)
mean(bear$Volume) 
if (mean(bull$Volume)>mean(bear$Volume)) { 
print("bull market volume is higher")
}
{
 print("bear market volume is higher") }
# Out:
# Warning message:
# "package 'dplyr' was built under R version 4.1.3"
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# [1] 5588666
# [1] 5817899
# [1] "bear market volume is higher"

# %%
#Problem 2

n = 1:100;
p = 0;
# use for loop to sum each term
for (k in n){
  # calculate each term an add to p
  p = p + ( (-1)^(k+1) / (2*k-1) );
}
# multiply p with 4 to get the final result
pi = 4 * p;



# use vector 1:100 at the place of k
vec_pi = 4 * sum(  (-1)^((1:100)+1) / (2*(1:100)-1) ) 

# print value of pi calculated by both methods
print(paste("Value of pi using for loop: ", pi))
print(paste("Value of pi using vectorization: ", vec_pi))
# Out:
# [1] "Value of pi using for loop:  3.13159290355855"
# [1] "Value of pi using vectorization:  3.13159290355855"

# %%
#Problem 3 

IBM <- read.csv("C:/Users/Administrator/data/IBM.csv") 
library(dplyr) 
bull <- filter(IBM, IBM$Open<IBM$Close) 
bear <- filter(IBM, IBM$Open>IBM$Close) 
bull
bear
mean(bull$Volume)
mean(bear$Volume) 
if (mean(bull$Volume)>mean(bear$Volume)) { 
print("bull market volume is higher")
}
{
 print("bear market volume is higher") }
# Out:
#     Date       Open     High     Low      Close    Adj.Close Volume
# 1   2018-01-03 150.4207 152.7820 149.4551 151.5201 122.1680   9875914
# 2   2018-01-04 152.6291 155.1816 152.3614 154.5889 124.6423   7903785
# 3   2018-01-05 155.2964 155.7361 154.0153 155.3442 125.2512   5434807
# 4   2018-01-08 155.5067 156.7017 154.5889 156.2811 126.0066   5478425
# 5   2018-01-10 155.7457 157.1033 155.3537 156.9599 126.5539   4366109
# 6   2018-01-17 160.6214 161.6922 159.9044 161.2333 129.9995  12248660
# 7   2018-01-22 154.4073 156.7686 154.0249 155.4493 125.3360   8870917
# 8   2018-01-23 155.6597 158.9484 155.3633 158.9388 128.1495   7809645
# 9   2018-01-26 158.8145 160.0478 158.4990 159.9809 128.9897   3962143
# 10  2018-02-06 143.6807 148.6520 142.5526 148.5086 119.7398  10321614
# 11  2018-02-09 142.0650 143.9197 138.0497 142.9350 116.3806   8188402
# 12  2018-02-12 144.2639 145.6979 143.6902 144.7419 117.8518   6151944
# ...
